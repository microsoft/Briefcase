# %%
# %config Application.log_level='WORKAROUND'
import logging
logging.getLogger('workspace').setLevel(logging.DEBUG)
# Out:
# ERROR:root:The 'log_level' trait of an IPKernelApp instance must be any of (0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL'), but a value of 'WORKAROUND' <class 'str'> was specified.

# %%
import os
os.chdir('python/tests/azure/msi')

# %%
import pyworkspace

ws = pyworkspace.Workspace()
# Out:
# DEBUG:workspace:workspace: /home/vsonline/workspace/python/tests/azure/msi/resources.yaml
# DEBUG:workspace:.env: /home/vsonline/workspace/python/tests/azure/msi/.env

# %%
ws['workspacetest1'].get_url()
# Out:
# DEBUG:workspace:secret probing: JupyterLabCredentialStore for workspacetest1.datasource ...
# DEBUG:workspace:secret probing: KeyRingCredentialProvider for workspacetest1.datasource ...
# DEBUG:workspace:secret probing: EnvironmentCredentialProvider for workspacetest1.datasource ...
# DEBUG:workspace:secret probing: DotEnvCredentialProvider for workspacetest1.datasource ...
# DEBUG:workspace:secret probing: JupyterLabCredentialStore for workspacetest1.credentialstore ...
# DEBUG:workspace:secret probing: KeyRingCredentialProvider for workspacetest1.credentialstore ...
# DEBUG:workspace:secret probing: EnvironmentCredentialProvider for workspacetest1.credentialstore ...
# DEBUG:workspace:secret probing: DotEnvCredentialProvider for workspacetest1.credentialstore ...
# ---------------------------------------------------------------------------
# KeyNotFoundException                      Traceback (most recent call last)
# ...

# %%
from msrestazure.azure_active_directory import MSIAuthentication


msi_auth = MSIAuthentication('https://management.core.windows.net/')
msi_auth.set_token()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     155         try:
# --> 156             conn = connection.create_connection(
#     157                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# ...
